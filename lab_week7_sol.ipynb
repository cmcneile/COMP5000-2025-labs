# %% [markdown]
# # Computer Lab Exercises week 7 (SOLUTIONS)

# %% [markdown]
# * These lab exercises are designed to introduce the basic ideas of numpy and pandas
# * These exercises are **not** part of the assessment of the Module.
# * I will post the solutions roughly 1 week after this file has been uploaded to the DLE.
# * Please note that pasting python from pdf can sometimes cause problems. For example quotation marks can sometimes be converted incorrectly, so then running python will cause errors.
#
# * See https://sites.google.com/view/pythonforstemstudents/home for a collection
# of links to information on python.
#
# See this overview of numpy  https://www.w3schools.com/python/numpy/numpy_intro.asp

# %% [markdown]
# ## Question 1a, Basic numpy
#
# Use numpy to calculate the mean of the numbers:  56, 25, 78, 89, 72

# %%
import numpy as np
# Put your solution here

data = np.array([56, 25, 78, 89, 72])
print("Mean = ", data.mean() )
# Out:
# Mean =  64.0

# %% [markdown]
# ##  Question 1b, Calculations with numpy
#
# The python code below shows the exam and coursework marks for four students.

# %%
import numpy as np

exam = np.array( [ 55 , 45 , 67 , 60   ]   ) 
coursework = np.array( [ 45 , 50 , 81, 34  ] )

# %% [markdown]
# The total mark for the module is 60% from the exam mark
# and 40% from coursework mark. Write some python code to compute the
# total mark for all four students and the mean of the total mark for
# the students. See
# https://scipy-lectures.org/intro/numpy/operations.html for some
# ideas.
#
# The output should like the below:
# <pre>
# Total marks for each student  [51.  47.  72.6 49.6]
# Class mean =  55.05 %
# </pre>

# %%
# Put your solution here

import numpy as np

exam = np.array( [ 55 , 45 , 67 , 60   ]   ) 
coursework = np.array( [ 45 , 50 , 81, 34  ] ) 

mark = 0.6 * exam + 0.4*coursework

print("Total marks for each student " , mark)
print("Class mean = " , np.mean(mark) , "%"  )
# Out:
# Total marks for each student  [51.  47.  72.6 49.6]
# Class mean =  55.05 %

# %% [markdown]
# ##  Question 1c, Working with multi-dimensional numpy arrays

# %% [markdown]
# Modify the python code below so that the script finds the maximum and minimum for each row.

# %%
import numpy as np
arr= np.array([[1,23,78],[98,60,75],[79,25,48]])  
print(arr)

print("Entire array, minimum " , np.amin(arr),
   "Maximum ", np.amax(arr))
# Out:
# [[ 1 23 78]
#  [98 60 75]
#  [79 25 48]]
# Entire array, minimum  1 Maximum  98

# %% [markdown]
# The final output should look something like:
# <pre>
# [[ 1 23 78]
#  [98 60 75]
#  [79 25 48]]
# Entire array, minimum  1 Maximum  98
# Row  0  of array , minimum=  1 maximum=  78
# Row  1  of array , minimum=  60 maximum=  98
# Row  2  of array , minimum=  25 maximum=  79
#
#
# </pre>

# %%
# Put your solution here

#https://data-flair.training/blogs/numpy-statistical-functions/

import numpy as np
arr= np.array([[1,23,78],[98,60,75],[79,25,48]])  
print(arr)

print("Entire array, minimum " , np.amin(arr),
   "Maximum ", np.amax(arr))

for i in range(0,3) :
  print("Row " , i , " of array , minimum= " , np.amin(arr[i,:]),
   "maximum= ", np.amax(arr[i,:]))
# Out:
# [[ 1 23 78]
#  [98 60 75]
#  [79 25 48]]
# Entire array, minimum  1 Maximum  98
# Row  0  of array , minimum=  1 maximum=  78
# Row  1  of array , minimum=  60 maximum=  98
# Row  2  of array , minimum=  25 maximum=  79

# %% [markdown]
# ## Question 1d, Working with multidimensional arrays
#
# * Modify the functiom **look_array** below so the array, the number of dimensions and the dimensions of the array is printed out.
# * The output should like:
#
# <pre>
# 42
# Number of dimensions  0
# Dimensions of the array  ()
#
# [1 2 3 4 5]
# Number of dimensions  1
# Dimensions of the array  (5,)
#
# [[1 2 3]
#  [4 5 6]]
# Number of dimensions  2
# Dimensions of the array  (2, 3)
#
# [[[ 1  2  3]
#   [ 4  5  6]]
#
#  [[-1 -2 -3]
#   [-4 -5 -6]]]
# Number of dimensions  3
# Dimensions of the array  (2, 2, 3)
# </pre>

# %%
import numpy as np

a = np.array(42)
b = np.array([1, 2, 3, 4, 5])
c = np.array([[1, 2, 3], [4, 5, 6]])
d = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])


def look_array(x_) :
   print("Number of dimensions ")
   print("Dimensions of the array " )
   print(" ")
    
look_array(a)
look_array(b)
look_array(c)
look_array(d)
# Out:
# Number of dimensions
# Dimensions of the array
#
# Number of dimensions
# Dimensions of the array
#
# Number of dimensions
# Dimensions of the array
#
# Number of dimensions
# Dimensions of the array

# %%
# Put your solution here
import numpy as np

a = np.array(42)
b = np.array([1, 2, 3, 4, 5])
c = np.array([[1, 2, 3], [4, 5, 6]])
d = np.array([[[1, 2, 3], [4, 5, 6]], [[-1, -2, -3], [-4, -5, -6]]])


def look_array(x_) :
   print(x_)
   print("Number of dimensions ", x_.ndim)
   print("Dimensions of the array " , x_.shape)
   print(" ")

look_array(a)
look_array(b)
look_array(c)
look_array(d)
# Out:
# 42
# Number of dimensions  0
# Dimensions of the array  ()
#
# [1 2 3 4 5]
# Number of dimensions  1
# Dimensions of the array  (5,)
#
# [[1 2 3]
#  [4 5 6]]
# Number of dimensions  2
# Dimensions of the array  (2, 3)
#
# [[[ 1  2  3]
#   [ 4  5  6]]
#
#  [[-1 -2 -3]
#   [-4 -5 -6]]]
# Number of dimensions  3
# Dimensions of the array  (2, 2, 3)

# %% [markdown]
# If you want you can update the code to  remove the brackets in the output
#
# <pre>
# 42
# Number of dimensions  0
# Dimensions of the array
#
# [1 2 3 4 5]
# Number of dimensions  1
# Dimensions of the array  5,
#
# [[1 2 3]
#  [4 5 6]]
# Number of dimensions  2
# Dimensions of the array  2, 3
#
# [[[ 1  2  3]
#   [ 4  5  6]]
#
#  [[-1 -2 -3]
#   [-4 -5 -6]]]
# Number of dimensions  3
# Dimensions of the array  2, 2, 3
# </pre>

# %%
# Put your solution here
import numpy as np

a = np.array(42)
b = np.array([1, 2, 3, 4, 5])
c = np.array([[1, 2, 3], [4, 5, 6]])
d = np.array([[[1, 2, 3], [4, 5, 6]], [[-1, -2, -3], [-4, -5, -6]]])


def look_array(x_) :
   print(x_)
   print("Number of dimensions ", x_.ndim)
   print("Dimensions of the array " , str(x_.shape).replace("(","").replace(")", ""))
   print(" ")

for xx in [a, b,c,d]:
   look_array(xx)
# Out:
# 42
# Number of dimensions  0
# Dimensions of the array
#
# [1 2 3 4 5]
# Number of dimensions  1
# Dimensions of the array  5,
#
# [[1 2 3]
#  [4 5 6]]
# Number of dimensions  2
# Dimensions of the array  2, 3
#
# [[[ 1  2  3]
#   [ 4  5  6]]
#
#  [[-1 -2 -3]
#   [-4 -5 -6]]]
# Number of dimensions  3
# Dimensions of the array  2, 2, 3

# %% [markdown]
# ## Question 2, Image processing with numpy
#
# The code below loads in the image and displays it. You will need to download the file smeaton.jpg from the DLE and put it in the same directory as the notebook.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# This image is on the DLE. It needs to be in the same directory as
# the python code.
ff = "smeaton.jpg"
img = mpimg.imread(ff)

plt.imshow(img)
plt.show()

# %% [markdown]
# The task is modify the code so that only the light house
# is shown. The final figure should look like figure below.
#
#
# * You should first find the dimensions of the images https://www.w3schools.com/python/numpy/numpy_array_shape.asp.
# * My solution uses array slicing https://www.w3schools.com/python/numpy/numpy_array_slicing.asp
# * There are machine learning algorithms, such as yolo (https://www.section.io/engineering-education/introduction-to-yolo-algorithm-for-object-detection/), which can do this.

# %%
# Put your solution here

ff = "smeaton.jpg"
import matplotlib.pyplot as plt

import matplotlib.image as mpimg
img = mpimg.imread(ff)

print(img.shape)

plt.imshow(img[:,600:800,:])
plt.show()
# Out:
# (558, 972, 3)

# %% [markdown]
# ##  Question 3, Basic use of  pandas
#
# The code below uses the pandas library
# (https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)
# to read the file "data-showing-sports-use-of-football-pitches.csv"
# (available from the DLE). The file contains information about how
# football pitches are used in Plymouth.
#
# The data set is from
# https://plymouth.thedata.place/dataset/football-pitches

# %%
import sys
import pandas as pd

fname = "data-showing-sports-use-of-football-pitches.csv"
football_df = pd.read_csv(fname)

print("Loaded data from  " , fname)

print(football_df)
# Out:
# Loaded data from   data-showing-sports-use-of-football-pitches.csv
#                                                  Name     Sub Area  \
# 0                                 AFC Plympton Ladies          NaN
# 1                                     Edgecumbe  F.C.          NaN
# 2                          Ocean City Powerchair F.C.          NaN
# 3                                   SB Frankfort F.C.          NaN
# 4                                     Signal Box F.C.          NaN
# ..                                                ...          ...
# 385  Devon  Disability Player Development Centre F.C.  Beacon Park
# 386                        Plymouth Argyle FITDC F.C.  Beacon Park
# 387                        Plymouth Argyle FITDC F.C.  Beacon Park
# 388                        Plymouth Argyle FITDC F.C.  Beacon Park
# 389                        Plymouth Argyle FITDC F.C.  Beacon Park
#
#                           Ground   Club ID             Team Name  \
# ...

# %% [markdown]
# The task is look to print the "Names" of the teams with the
# column 'Adult male 11v11 (16-45)' is equal to 1. Your code should just print out the
# top 4 rows with this condition.
#
# The output should look like:
# <pre>
# Loaded data from   data-showing-sports-use-of-football-pitches.csv
# 1                              Edgecumbe  F.C.
# 2                   Ocean City Powerchair F.C.
# 5    Ivybridge Community College - PAFITC F.C.
# 6    Ivybridge Community College - PAFITC F.C.
# Name: Name, dtype: object
#
# </pre>

# %%
# Put your solution here
import sys
import pandas as pd

fname = "data-showing-sports-use-of-football-pitches.csv"
football_df = pd.read_csv(fname)

print("Loaded data from  " , fname)

male_team_ = football_df[football_df['Adult male 11v11 (16-45)']==1]

print(male_team_["Name"].head(4))
# Out:
# Loaded data from   data-showing-sports-use-of-football-pitches.csv
# 1                              Edgecumbe  F.C.
# 2                   Ocean City Powerchair F.C.
# 5    Ivybridge Community College - PAFITC F.C.
# 6    Ivybridge Community College - PAFITC F.C.
# Name: Name, dtype: object

# %% [markdown]
# ## Question 4
#
# This question uses data about the river level of EXETER OLD PINN LANE
# The data is taken from https://riverlevels.uk/exeter-old-pinn-lane-devon#google_vignette
# and the csv file exeter-old-pinn-lane-devon.csv is also available on the DLE

# %%
import pandas as pd
river_data = "exeter-old-pinn-lane-devon.csv"
river_df = pd.read_csv(river_data)
river_df.head()
# Out:
#          date  min_level  avg_level  max_level
# 0  2022-05-22      0.000      0.001      0.002
# 1  2022-05-23      0.007      0.007      0.007
# 2  2022-05-24     -0.019      0.005      0.017
# 3  2022-05-25      0.006      0.008      0.012
# 4  2022-05-26      0.005      0.007      0.009

# %% [markdown]
# Plot the avg_level versus date
#
# See the documentation here  https://www.w3schools.com/python/pandas/pandas_plotting.asp

# %%
# put your solution here

river_df.plot(x="date" , y = "avg_level")
# Out:
# <Axes: xlabel='date'>

# %%
river_df["avg_level"].hist()
# Out:
# <Axes: >

# %%
river_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       894 non-null    object
#  1   min_level  894 non-null    float64
#  2   avg_level  894 non-null    float64
#  3   max_level  894 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 28.1+ KB

# %%
river_df.max()
# Out:
# date         2024-10-31
# min_level         0.252
# avg_level         0.253
# max_level           0.3
# dtype: object

# %% [markdown]
# Find the dates when the avg_level was greater than 0.24

# %%
df_large = river_df[river_df["avg_level"]> 0.24]

# %%
print(df_large["date"].to_string(index=False))
# Out:
# 2022-08-31
# 2022-09-04
# 2022-09-14
# 2022-09-16
# 2022-09-17
# 2022-09-18
# 2022-09-24
# 2022-09-25
